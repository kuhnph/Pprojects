# %%
import pandas as pd

df = pd.read_parquet('output.parquet')

df['pn']
# Out:
# 0        0.000000
# 1        0.999993
# 2        1.999979
# 3        2.999957
# 4        3.999926
#           ...
# 395    364.915253
# 396    365.680450
# 397    366.444672
# 398    367.207886
# 399    367.970123
# Name: pn, Length: 400, dtype: float32
